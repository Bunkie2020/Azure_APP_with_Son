# %%
##Our Code Test App

import docx
import os
import docxtpl
from docxtpl import DocxTemplate




import xlsxwriter
from docx.shared import Inches
doc = docx.Document()
doc.add_heading("ME and SON Like the Wrigt Brothers ( Rsquared)" ,1)

parag = doc.add_paragraph("                                GF No________________________"               )

paragspace = doc.add_paragraph(" ")


parag2 = doc.add_paragraph(" ")

parag2.add_run("                                    SIGNATURE ADDENDUM"                    ).bold =True

parag2= doc.add_paragraph(" ")
parag2.add_run("                                                        to     "                         ).bold=True
parag2= doc.add_paragraph(" ")
parag2.add_run("                                            BORROWER'S                    "         ).bold =True
parag2= doc.add_paragraph(" ")
parag2.add_run("                                     CLOSING STATEMENT                       "     ).bold =True
doc.add_paragraph("Like Father Like Son, we are About to Buck").bold=True

parag3 = doc.add_paragraph("")
parag4 = doc.add_paragraph("")


doc.add_paragraph("BY:_______________")

parag7 = doc.add_paragraph("")

parag8 = doc.add_paragraph("")

doc.add_paragraph("By:_______________")
doc.add_picture('pam.jpg', width = Inches(2.5))
#parag.add_run("This word document was created Python code")
doc.save("Chicago_Title_Signature_Addendum.docx")
os.system("start Chicago_Title_Signature_Addendum.docx")




doc2 = docx.Document()

parag2doc = doc2.add_paragraph("                                Survey Affidavit T-47"               )
paragspace2doc = doc2.add_paragraph(" ")


parag22doc = doc2.add_paragraph(" ")

parag22doc.add_run("Date                    ______, 20__")

parag22doc =doc2.add_paragraph("GF No.")
parag22doc =doc2.add_paragraph(" Name of Affidavit    "         )
parag22doc=doc2.add_paragraph(" Addrees of Affidavit ")
parag22doc=doc2.add_paragraph(" Description of Property   SEE attached Exibit A"     )
parag22doc=doc2.add_paragraph("Name of Title Company")
##doc2.add_run("Chicago Title Company")
parag22doc =doc2.add_paragraph("Like Father Like Son, we are About to Buck").bold=True

parag32doc = doc2.add_paragraph("")
parag42doc = doc2.add_paragraph("")


doc2.add_paragraph("BY:_______________")

parag72doc = doc.add_paragraph("")

parag82doc = doc.add_paragraph("")

doc2.add_paragraph("By:_______________")
#parag.add_run("This word document was created Python code")
doc.save("Survey_Affidavit.docx")
os.system("start Survey_Affidavit.docx")



doc3 = docx.Document()

parag3doc = doc3.add_paragraph("                                Survey Affidavit T-47"               )
paragspace3doc = doc3.add_paragraph(" ")


parag22doc = doc2.add_paragraph(" ")

parag22doc.add_run("Date                    ______, 20__")

parag22doc =doc2.add_paragraph("GF No.")
parag22doc =doc2.add_paragraph(" Name of Affidavit    "         )
parag22doc=doc2.add_paragraph(" Addrees of Affidavit ")
parag22doc=doc2.add_paragraph(" Description of Property   SEE attached Exibit A"     )
parag22doc=doc2.add_paragraph("Name of Title Company")
##doc2.add_run("Chicago Title Company")
parag22doc =doc2.add_paragraph("Like Father Like Son, we are About to Buck").bold=True

parag32doc = doc2.add_paragraph("")
parag42doc = doc2.add_paragraph("")


doc2.add_paragraph("BY:_______________")

parag72doc = doc.add_paragraph("")

parag82doc = doc.add_paragraph("")

doc2.add_paragraph("By:_______________")
#parag.add_run("This word document was created Python code")
doc.save("AFFIDAVIT_AS_TO_DEBTS_LIENS_AND_POSSESION.docx")
os.system("AFFIDAVIT_AS_TO_DEBTS_LIENS_AND_POSSESION.docx")



workbook = xlsxwriter.Workbook('C:/Fall SMU Mod B/ITOM 6222 Business Forecast Engineering Models/ProjectRepo/FATHER_LIKE_SON.XLSX')
worksheet = workbook.add_worksheet()
worksheet.write('A1','Welcome to Python')
worksheet.write('A2', 'Son and I are the Baddest on the Plannet')
workbook.close()
os.system("FATHER_LIKE_SON.XLSX")
